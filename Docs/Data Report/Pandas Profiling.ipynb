# %%
# !pip uninstall pandas-profiling

# %%
# !pip install pandas-profiling[notebook,html]

# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

filepath_math = 'https://raw.githubusercontent.com/arunk13/MSDA-Assignments/master/IS607Fall2015/Assignment3/student-mat.csv'
filepath_por =  'https://raw.githubusercontent.com/arunk13/MSDA-Assignments/master/IS607Fall2015/Assignment3/student-por.csv'


df = pd.read_csv(filepath_math, sep=';')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df.head(3)
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences G1 G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6  5  6   6
# 1     GP   F   17       U     GT3       T  ...     1       3        4  5  5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10  7  8  10
#
# [3 rows x 33 columns]

# %%
profile = ProfileReport(df, title="Pandas Profiling Report")

# %%
profile.to_file("your_report.html")

# %%
profile
# Out:
# Output hidden; open in https://colab.research.google.com to view.
